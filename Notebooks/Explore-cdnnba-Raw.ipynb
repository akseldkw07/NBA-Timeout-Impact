# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from kret_notebook import *  # NOTE import first
from kret_lgbm._core.lgbm_nb_imports import *
from kret_lightning._core.lightning_nb_imports import *
from kret_matplotlib._core.mpl_nb_imports import *
from kret_np_pd._core.np_pd_nb_imports import *
from kret_optuna._core.optuna_nb_imports import *
from kret_polars._core.polars_nb_imports import *
from kret_rosetta._core.rosetta_nb_imports import *
from kret_sklearn._core.sklearn_nb_imports import *
from kret_torch_utils._core.torch_nb_imports import *
from kret_tqdm._core.tqdm_nb_imports import *
from kret_type_hints._core.types_nb_imports import *
from kret_utils._core.utils_nb_imports import *

# from kret_wandb._core.wandb_nb_imports import *  # NOTE this is slow to import
# Out:
# Loaded environment variables from /home/Akseldkw/coding/nba/NBA-Timeout-Impact/.env
# [kret_lgbm._core.lgbm_nb_imports] Imported kret_lgbm._core.lgbm_nb_imports in 1.7195 seconds
# [kret_lightning._core.lightning_nb_imports] Imported kret_lightning._core.lightning_nb_imports in 4.8798 seconds
# [kret_matplotlib._core.mpl_nb_imports] Imported kret_matplotlib._core.mpl_nb_imports in 0.2538 seconds
# [kret_np_pd._core.np_pd_nb_imports] Imported kret_np_pd._core.np_pd_nb_imports in 0.0007 seconds
# [kret_optuna._core.optuna_nb_imports] Imported kret_optuna._core.optuna_nb_imports in 0.0006 seconds
# [kret_polars._core.polars_nb_imports] Imported kret_polars._core.polars_nb_imports in 0.3428 seconds
# [kret_rosetta._core.rosetta_nb_imports] Imported kret_rosetta._core.rosetta_nb_imports in 0.0000 seconds
# [kret_sklearn._core.sklearn_nb_imports] Imported kret_sklearn._core.sklearn_nb_imports in 0.0301 seconds
# [kret_torch_utils._core.torch_nb_imports] Imported kret_torch_utils._core.torch_nb_imports in 0.1489 seconds
# [kret_tqdm._core.tqdm_nb_imports] Imported kret_tqdm._core.tqdm_nb_imports in 0.0001 seconds
# [kret_type_hints._core.types_nb_imports] Imported kret_type_hints._core.types_nb_imports in 0.0005 seconds
# [kret_utils._core.utils_nb_imports] Imported kret_utils._core.utils_nb_imports in 0.0004 seconds

# %%
from nba_timeout_impact.nb_imports import *

# %% [markdown]
# # Load Data

# %%
cdnnba = NBADataLoader.load_seasons(data_type="cdnnba", playoffs=False)
# Out:
# Loading data_type='cdnnba', seasons=[2020, 2021, 2022, 2023, 2024, 2025], playoffs=False...
# /home/Akseldkw/coding/nba/NBA-Timeout-Impact/nba_timeout_impact/data_pipes/load_data_utils.py:128: DtypeWarning: Columns (0: isTargetScoreLastPeriod, 1: shortFormattedClock) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(f, **read_csv_kwargs)

# %%
cdnnba_playoff = NBADataLoader.load_seasons(data_type="cdnnba", playoffs=True)
# Out:
# Loading data_type='cdnnba', seasons=[2020, 2021, 2022, 2023, 2024], playoffs=True...

# %%
UKS_NP_PD.dtt([cdnnba, cdnnba_playoff], show_dims=True, num_cols=1)
# Out:
# <div id='dtt-375465'><div style='display: flex; flex-direction: column; gap: 20px; overflow-x: auto;'>
#         <style>
#             #dtt-375465 table td, #dtt-375465 table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             #dtt-375465 table td {
#                 text-overflow: ellipsis;
#             }
#             #dtt-375465 table td.truncated::after, #dtt-375465 table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('#dtt-375465 table td, #dtt-375465 table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                             // Expand truncated cells up to max_col_width so content
#                             // is as visible as possible without forcing non-truncated
#                             // cells to be wider than their natural size
#                             cell.style.width = '150px';
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style='display: flex; gap: 20px; flex-shrink: 0; overflow: hidden; width: fit-content;'><div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>actionNumber</th>
#       <th>clock</th>
#       <th>timeActual</th>
#       <th>period</th>
#       <th>periodType</th>
#       <th>actionType</th>
#       <th>subType</th>
#       <th>qualifiers</th>
#       <th>personId</th>
#       <th>x</th>
#       <th>y</th>
#       <th>possession</th>
#       <th>scoreHome</th>
#       <th>scoreAway</th>
#       <th>edited</th>
#       <th>orderNumber</th>
#       <th>xLegacy</th>
#       <th>yLegacy</th>
#       <th>isFieldGoal</th>
#       <th>side</th>
#       <th>description</th>
#       <th>personIdsFilter</th>
#       <th>teamId</th>
#       <th>teamTricode</th>
#       <th>descriptor</th>
#       <th>jumpBallRecoveredName</th>
#       <th>jumpBallWonPlayerName</th>
#       <th>jumpBallWonPersonId</th>
#       <th>jumpBallLostPlayerName</th>
#       <th>jumpBallLostPersonId</th>
#       <th>officialId</th>
#       <th>turnoverTotal</th>
#       <th>playerName</th>
#       <th>playerNameI</th>
#       <th>foulPersonalTotal</th>
#       <th>foulTechnicalTotal</th>
#       <th>foulDrawnPlayerName</th>
#       <th>foulDrawnPersonId</th>
#       <th>shotResult</th>
#       <th>pointsTotal</th>
#       <th>shotDistance</th>
#       <th>assistPlayerNameInitial</th>
#       <th>assistPersonId</th>
#       <th>assistTotal</th>
#       <th>shotActionNumber</th>
#       <th>reboundTotal</th>
#       <th>reboundDefensiveTotal</th>
#       <th>reboundOffensiveTotal</th>
#       <th>blockPlayerName</th>
#       <th>blockPersonId</th>
#       <th>jumpBallRecoverdPersonId</th>
#       <th>stealPlayerName</th>
#       <th>stealPersonId</th>
#       <th>gameId</th>
#       <th>value</th>
#       <th>area</th>
#       <th>areaDetail</th>
#       <th>isTargetScoreLastPeriod</th>
#       <th>shortFormattedClock</th>
#       <th>jerseyNumber</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>int64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>object</th>
#       <th>str</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>323619</th>
#       <td>598</td>
#       <td>PT06M42.00S</td>
#       <td>2021-03-12T03:03:30.600Z</td>
#       <td>4</td>
#       <td>REGULAR</td>
#       <td>foul</td>
#       <td>personal</td>
#       <td>NaN</td>
#       <td>1630183</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1610612740</td>
#       <td>91</td>
#       <td>121</td>
#       <td>2021-03-12T03:03:52Z</td>
#       <td>5940000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>J. McDaniels personal FOUL (4 PF)</td>
#       <td>1630183, 1629638</td>
#       <td>1610612750.000</td>
#       <td>MIN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>203591.000</td>
#       <td>NaN</td>
#       <td>McDaniels</td>
#       <td>J. McDaniels</td>
#       <td>4.000</td>
#       <td>0.000</td>
#       <td>Alexander-Walker</td>
#       <td>1629638.000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>22000574</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>932058</th>
#       <td>455</td>
#       <td>PT10M10.00S</td>
#       <td>2022-01-07T02:19:56.200Z</td>
#       <td>4</td>
#       <td>REGULAR</td>
#       <td>rebound</td>
#       <td>defensive</td>
#       <td>NaN</td>
#       <td>1629057</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1610612738</td>
#       <td>82</td>
#       <td>87</td>
#       <td>2022-01-07T02:19:59Z</td>
#       <td>4450000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>R. Williams III REBOUND (Off:3 Def:4)</td>
#       <td>1629057</td>
#       <td>1610612738.000</td>
#       <td>BOS</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Williams III</td>
#       <td>R. Williams III</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>453.000</td>
#       <td>7.000</td>
#       <td>4.000</td>
#       <td>3.000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>22100578</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1137394</th>
#       <td>298</td>
#       <td>PT03M17.00S</td>
#       <td>2022-03-04T02:32:19.500Z</td>
#       <td>2</td>
#       <td>REGULAR</td>
#       <td>stoppage</td>
#       <td>out-of-bounds</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>

# %% [markdown]
# # Implementation

# %% [markdown]
# # Sandbox
