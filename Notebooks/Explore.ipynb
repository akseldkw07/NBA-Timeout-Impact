# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from kret_notebook import *  # NOTE import first
from kret_lgbm._core.lgbm_nb_imports import *
from kret_lightning._core.lightning_nb_imports import *
from kret_matplotlib._core.mpl_nb_imports import *
from kret_np_pd._core.np_pd_nb_imports import *
from kret_optuna._core.optuna_nb_imports import *
from kret_polars._core.polars_nb_imports import *
from kret_rosetta._core.rosetta_nb_imports import *
from kret_sklearn._core.sklearn_nb_imports import *
from kret_torch_utils._core.torch_nb_imports import *
from kret_tqdm._core.tqdm_nb_imports import *
from kret_type_hints._core.types_nb_imports import *
from kret_utils._core.utils_nb_imports import *

# from kret_wandb._core.wandb_nb_imports import *  # NOTE this is slow to import
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/Columbia/NBA-Timeout-Impact/.env
# [kret_lgbm._core.lgbm_nb_imports] Imported kret_lgbm._core.lgbm_nb_imports in 2.0715 seconds
# [kret_lightning._core.lightning_nb_imports] Imported kret_lightning._core.lightning_nb_imports in 4.2922 seconds
# [kret_matplotlib._core.mpl_nb_imports] Imported kret_matplotlib._core.mpl_nb_imports in 0.3133 seconds
# [kret_np_pd._core.np_pd_nb_imports] Imported kret_np_pd._core.np_pd_nb_imports in 0.0006 seconds
# [kret_optuna._core.optuna_nb_imports] Imported kret_optuna._core.optuna_nb_imports in 0.0008 seconds
# [kret_polars._core.polars_nb_imports] Imported kret_polars._core.polars_nb_imports in 0.0963 seconds
# [kret_rosetta._core.rosetta_nb_imports] Imported kret_rosetta._core.rosetta_nb_imports in 0.0000 seconds
# [kret_sklearn._core.sklearn_nb_imports] Imported kret_sklearn._core.sklearn_nb_imports in 0.1984 seconds
# [kret_torch_utils._core.torch_nb_imports] Imported kret_torch_utils._core.torch_nb_imports in 0.3956 seconds
# [kret_tqdm._core.tqdm_nb_imports] Imported kret_tqdm._core.tqdm_nb_imports in 0.0002 seconds
# [kret_type_hints._core.types_nb_imports] Imported kret_type_hints._core.types_nb_imports in 0.0006 seconds
# [kret_utils._core.utils_nb_imports] Imported kret_utils._core.utils_nb_imports in 0.0009 seconds

# %%
from nba_timeout_impact.data_utils import *

# %% [markdown]
# # Load Data

# %%
ret = available_seasons(data_type="nbastats")

# %%
ret
# Out:
# [1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023,
#  2024]

# %%
nba_stats = load_seasons(data_type="nbastats", playoffs=True)

# %%
UKS_NP_PD.dtt([nba_stats], show_dims=True)
# Out:
# <div id='dtt-625697'><div style='display: flex; gap: 20px; overflow-x: auto;'>
#         <style>
#             #dtt-625697 table td, #dtt-625697 table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             #dtt-625697 table td {
#                 text-overflow: ellipsis;
#             }
#             #dtt-625697 table td.truncated::after, #dtt-625697 table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('#dtt-625697 table td, #dtt-625697 table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                             // Expand truncated cells up to max_col_width so content
#                             // is as visible as possible without forcing non-truncated
#                             // cells to be wider than their natural size
#                             cell.style.width = '150px';
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>GAME_ID</th>
#       <th>EVENTNUM</th>
#       <th>EVENTMSGTYPE</th>
#       <th>EVENTMSGACTIONTYPE</th>
#       <th>PERIOD</th>
#       <th>WCTIMESTRING</th>
#       <th>PCTIMESTRING</th>
#       <th>HOMEDESCRIPTION</th>
#       <th>NEUTRALDESCRIPTION</th>
#       <th>VISITORDESCRIPTION</th>
#       <th>SCORE</th>
#       <th>SCOREMARGIN</th>
#       <th>PERSON1TYPE</th>
#       <th>PLAYER1_ID</th>
#       <th>PLAYER1_NAME</th>
#       <th>PLAYER1_TEAM_ID</th>
#       <th>PLAYER1_TEAM_CITY</th>
#       <th>PLAYER1_TEAM_NICKNAME</th>
#       <th>PLAYER1_TEAM_ABBREVIATION</th>
#       <th>PERSON2TYPE</th>
#       <th>PLAYER2_ID</th>
#       <th>PLAYER2_NAME</th>
#       <th>PLAYER2_TEAM_ID</th>
#       <th>PLAYER2_TEAM_CITY</th>
#       <th>PLAYER2_TEAM_NICKNAME</th>
#       <th>PLAYER2_TEAM_ABBREVIATION</th>
#       <th>PERSON3TYPE</th>
#       <th>PLAYER3_ID</th>
#       <th>PLAYER3_NAME</th>
#       <th>PLAYER3_TEAM_ID</th>
#       <th>PLAYER3_TEAM_CITY</th>
#       <th>PLAYER3_TEAM_NICKNAME</th>
#       <th>PLAYER3_TEAM_ABBREVIATION</th>
#       <th>VIDEO_AVAILABLE_FLAG</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>int64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>14986</th>
#       <td>41800161</td>
#       <td>567</td>
#       <td>8</td>
#       <td>0</td>
#       <td>4</td>
#       <td>5:36 PM</td>
#       <td>8:01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>SUB: Westbrook FOR Felton</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5.000</td>
#       <td>101109</td>
#       <td>Raymond Felton</td>
#       <td>1610612760.000</td>
#       <td>Oklahoma City</td>
#       <td>Thunder</td>
#       <td>OKC</td>
#       <td>5</td>
#       <td>201566</td>
#       <td>Russell Westbrook</td>
#       <td>1610612760.000</td>
#       <td>Oklahoma City</td>
#       <td>Thunder</td>
#       <td>OKC</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>27595</th>
#       <td>41800226</td>
#       <td>242</td>
#       <td>2</td>
#       <td>73</td>
#       <td>2</td>
#       <td>9:58 PM</td>
#       <td>7:18</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>MISS Curry 3' Driving Reverse Layup</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5.000</td>
#       <td>201939</td>
#       <td>Stephen Curry</td>
#       <td>1610612744.000</td>
#       <td>Golden State</td>
#       <td>Warriors</td>
#       <td>GSW</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>45490</th>
#       <td>41900131</td>
#       <td>298</td>
#       <td>3</td>
#       <td>11</td>
#       <td>2</td>
#       <td>5:09 PM</td>
#       <td>1:29</td>
#       <td>Brogdon Free Throw 1 of 2 (7 PTS)</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>52 - 49</td>
#       <td>-3</td>
#       <td>4.000</td>
#       <td>1627763</td>
#       <td>Malcolm Brogdon</td>
#       <td>1610612754.000</td>
#       <td>Indiana</td>
#       <td>Pacers</td>
#       <td>IND</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>104731</th>
#       <td>42000222</td>
#       <td>34</td>
#       <td>6</td>
#       <td>2</td>
#       <td>1</td>
#       <td>10:30 PM</td>
#       <td>8:27</td>
#       <td>Bogdanovic S.FOUL (P1.T1) (T.Maddox)</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.000</td>
#       <td>202711</td>
#       <td>Bojan Bogdanovic</td>
#       <td>1610612762.000</td>
#       <td>Utah</td>
#       <td>Jazz</td>
#       <td>UTA</td>
#       <td>5</td>
#       <td>1627826</td>
#       <td>Ivica Zubac</td>
#       <td>1610612746.000</td>
#       <td>LA</td>
#       <td>Clippers</td>
#       <td>LAC</td>
#       <td>1</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>119061</th>
#       <td>42100105</td>
#       <td>656</td>
#       <td>4</td>
#       <td>0</td>
#       <td>4</td>
#       <td>9:48 PM</td>
#       <td>0:29</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Hawks Rebound</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>3.000</td>
#       <td>1610612737</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#   </tbody>
#   <tfoot>
#     <tr><td colspan="35" style="text-align: left; font-size: 0.8em; color: #888; font-style: italic; padding: 4px 8px;">Showing 5 of 194,771 rows × 34 columns</td></tr>
#   </tfoot>
# </table></div></div></div>

# %%
nba_statsv3 = load_seasons(data_type="nbastatsv3", playoffs=True)

# %%
UKS_NP_PD.dtt([nba_statsv3], show_dims=True)
# Out:
# <div id='dtt-413663'><div style='display: flex; gap: 20px; overflow-x: auto;'>
#         <style>
#             #dtt-413663 table td, #dtt-413663 table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             #dtt-413663 table td {
#                 text-overflow: ellipsis;
#             }
#             #dtt-413663 table td.truncated::after, #dtt-413663 table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('#dtt-413663 table td, #dtt-413663 table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                             // Expand truncated cells up to max_col_width so content
#                             // is as visible as possible without forcing non-truncated
#                             // cells to be wider than their natural size
#                             cell.style.width = '150px';
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>actionNumber</th>
#       <th>clock</th>
#       <th>period</th>
#       <th>teamId</th>
#       <th>teamTricode</th>
#       <th>personId</th>
#       <th>playerName</th>
#       <th>playerNameI</th>
#       <th>xLegacy</th>
#       <th>yLegacy</th>
#       <th>shotDistance</th>
#       <th>shotResult</th>
#       <th>isFieldGoal</th>
#       <th>scoreHome</th>
#       <th>scoreAway</th>
#       <th>pointsTotal</th>
#       <th>location</th>
#       <th>description</th>
#       <th>actionType</th>
#       <th>subType</th>
#       <th>videoAvailable</th>
#       <th>actionId</th>
#       <th>gameId</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>int64</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9736</th>
#       <td>329</td>
#       <td>PT00M58.50S</td>
#       <td>2</td>
#       <td>1610612746</td>
#       <td>LAC</td>
#       <td>101150</td>
#       <td>Williams</td>
#       <td>L. Williams</td>
#       <td>93</td>
#       <td>34</td>
#       <td>10</td>
#       <td>Made</td>
#       <td>1</td>
#       <td>68.000</td>
#       <td>50.000</td>
#       <td>118</td>
#       <td>v</td>
#       <td>Williams 10' Driving Floating Jump Shot (7 PTS)</td>
#       <td>Made Shot</td>
#       <td>Driving Floating Jump Shot</td>
#       <td>1</td>
#       <td>235</td>
#       <td>41800142</td>
#     </tr>
#     <tr>
#       <th>18001</th>
#       <td>270</td>
#       <td>PT01M19.00S</td>
#       <td>2</td>
#       <td>1610612745</td>
#       <td>HOU</td>
#       <td>101108</td>
#       <td>Paul</td>
#       <td>C. Paul</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>h</td>
#       <td>Paul S.FOUL (P1.T4) (J.Goble)</td>
#       <td>Foul</td>
#       <td>Shooting</td>
#       <td>1</td>
#       <td>199</td>
#       <td>41800171</td>
#     </tr>
#     <tr>
#       <th>21573</th>
#       <td>353</td>
#       <td>PT10M02.00S</td>
#       <td>3</td>
#       <td>1610612749</td>
#       <td>MIL</td>
#       <td>203114</td>
#       <td>Middleton</td>
#       <td>K. Middleton</td>
#       <td>-13</td>
#       <td>267</td>
#       <td>27</td>
#       <td>Made</td>
#       <td>1</td>
#       <td>62.000</td>
#       <td>62.000</td>
#       <td>124</td>
#       <td>v</td>
#       <td>Middleton 27' 3PT Jump Shot (7 PTS) (Bledsoe 3 AST)</td>
#       <td>Made Shot</td>
#       <td>Jump Shot</td>
#       <td>1</td>
#       <td>249</td>
#       <td>41800203</td>
#     </tr>
#     <tr>
#       <th>125076</th>
#       <td>277</td>
#       <td>PT06M34.00S</td>
#       <td>2</td>
#       <td>1610612738</td>
#       <td>BOS</td>
#       <td>203935</td>
#       <td>Smart</td>
#       <td>M. Smart</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>h</td>
#       <td>Smart Lost Ball Turnover (P3.T7)</td>
#       <td>Turnover</td>
#       <td>Lost Ball</td>
#       <td>1</td>
#       <td>198</td>
#       <td>42100111</td>
#     </tr>
#     <tr>
#       <th>155667</th>
#       <td>462</td>
#       <td>PT04M14.00S</td>
#       <td>3</td>
#       <td>1610612744</td>
#       <td>GSW</td>
#       <td>202691</td>
#       <td>Thompson</td>
#       <td>K. Thompson</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>h</td>
#       <td>Thompson Out of Bounds - Bad Pass Turnover Turnover (P3.T16)</td>
#       <td>Turnover</td>
#       <td>Out of Bounds - Bad Pass Turnover</td>
#       <td>1</td>
#       <td>354</td>
#       <td>42100236</td>
#     </tr>
#   </tbody>
#   <tfoot>
#     <tr><td colspan="24" style="text-align: left; font-size: 0.8em; color: #888; font-style: italic; padding: 4px 8px;">Showing 5 of 204,450 rows × 23 columns</td></tr>
#   </tfoot>
# </table></div></div></div>

# %%
cdnnba = load_seasons(data_type="cdnnba", playoffs=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cdnnba= load_seasons(data_type="cdnnba", playoffs=True)
#
# File ~/coding/Columbia/NBA-Timeout-Impact/nba_timeout_impact/data_utils.py:117, in load_seasons(data_type, seasons, playoffs)
#     115 if isinstance(seasons, int):
#     116     seasons = [seasons]
# --> 117 frames = [load_season(data_type, s, playoffs) for s in seasons]
#     118 return pd.concat(frames, ignore_index=True)
#
# File ~/coding/Columbia/NBA-Timeout-Impact/nba_timeout_impact/data_utils.py:97, in load_season(data_type, season, playoffs)
#      95 path = _tar_path(data_type, season, playoffs)
#      96 if not path.exists():
# ---> 97     raise FileNotFoundError(
#      98         f"Dataset not found: {path}\n" f"Available files: {sorted(NBA_DATA_DIR.glob(f'{data_type}_*.tar.xz'))}"
#      99     )
#     100 csv_name = path.stem.replace(".tar", "") + ".csv"  # strip .tar from stem
#     101 # stem of "nbastats_2022.tar.xz" is "nbastats_2022.tar", so:
#
# FileNotFoundError: Dataset not found: /Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_po_2018.tar.xz
# Available files: [PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_2020.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_2021.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_2022.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_2023.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_2024.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_2025.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_po_2020.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_po_2021.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_po_2022.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_po_2023.tar.xz'), PosixPath('/Users/Akseldkw/coding/Columbia/nba_data/datasets/cdnnba_po_2024.tar.xz')]

# %%
UKS_NP_PD.dtt([cdnnba], show_dims=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 UKS_NP_PD.dtt([cdnnba], show_dims=True)
#
# NameError: name 'cdnnba' is not defined

# %%
data_nba = load_seasons(data_type="datanba", playoffs=True)
# Out:
# /Users/Akseldkw/coding/Columbia/NBA-Timeout-Impact/nba_timeout_impact/data_utils.py:106: DtypeWarning: Columns (0: wallclk) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(f)

# %%
UKS_NP_PD.dtt([data_nba], show_dims=True)
# Out:
# <div id='dtt-974102'><div style='display: flex; gap: 20px; overflow-x: auto;'>
#         <style>
#             #dtt-974102 table td, #dtt-974102 table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             #dtt-974102 table td {
#                 text-overflow: ellipsis;
#             }
#             #dtt-974102 table td.truncated::after, #dtt-974102 table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('#dtt-974102 table td, #dtt-974102 table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                             // Expand truncated cells up to max_col_width so content
#                             // is as visible as possible without forcing non-truncated
#                             // cells to be wider than their natural size
#                             cell.style.width = '150px';
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>evt</th>
#       <th>cl</th>
#       <th>de</th>
#       <th>locX</th>
#       <th>locY</th>
#       <th>opt1</th>
#       <th>opt2</th>
#       <th>mtype</th>
#       <th>etype</th>
#       <th>opid</th>
#       <th>tid</th>
#       <th>pid</th>
#       <th>hs</th>
#       <th>vs</th>
#       <th>epid</th>
#       <th>oftid</th>
#       <th>ord</th>
#       <th>PERIOD</th>
#       <th>GAME_ID</th>
#       <th>wallclk</th>
#       <th>opt3</th>
#       <th>opt4</th>
#       <th>pts</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>int64</th>
#       <th>str</th>
#       <th>str</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>float64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>float64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>str</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>40065</th>
#       <td>620</td>
#       <td>02:49</td>
#       <td>[GSW] Cousins Free Throw 2 of 2 Missed</td>
#       <td>0</td>
#       <td>-80</td>
#       <td>2</td>
#       <td>0</td>
#       <td>12</td>
#       <td>3</td>
#       <td>NaN</td>
#       <td>1610612744</td>
#       <td>202326</td>
#       <td>102</td>
#       <td>106</td>
#       <td>NaN</td>
#       <td>1610612744</td>
#       <td>6100000</td>
#       <td>4</td>
#       <td>41800406</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>132331</th>
#       <td>300</td>
#       <td>04:00</td>
#       <td>[MIN] Vanderbilt Rebound (Off:3 Def:4)</td>
#       <td>1</td>
#       <td>9</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4</td>
#       <td>NaN</td>
#       <td>1610612750</td>
#       <td>1629020</td>
#       <td>51</td>
#       <td>32</td>
#       <td>NaN</td>
#       <td>1610612750</td>
#       <td>2970000</td>
#       <td>2</td>
#       <td>42100153</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>155755</th>
#       <td>563</td>
#       <td>07:07</td>
#       <td>[GSW] Moody Foul: Shooting (1 PF) (2 FTA) (E Lewis)</td>
#       <td>-71</td>
#       <td>38</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>6</td>
#       <td>203493.000</td>
#       <td>1610612744</td>
#       <td>1630541</td>
#       <td>99</td>
#       <td>92</td>
#       <td>NaN</td>
#       <td>1610612742</td>
#       <td>5560000</td>
#       <td>4</td>
#       <td>42100312</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>184788</th>
#       <td>136</td>
#       <td>00:44.4</td>
#       <td>[PHI] Melton Foul: Personal (1 PF) (J Williams)</td>
#       <td>-150</td>
#       <td>222</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>6</td>
#       <td>1627763.000</td>
#       <td>1610612755</td>
#       <td>1629001</td>
#       <td>27</td>
#       <td>19</td>
#       <td>202058.000</td>
#       <td>1610612738</td>
#       <td>1360000</td>
#       <td>1</td>
#       <td>42200214</td>
#       <td>2023-05-07T20:10:28.200Z</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>190663</th>
#       <td>666</td>
#       <td>05:44</td>
#       <td>[GSW] Moody Substitution replaced by Lamb</td>
#       <td>0</td>
#       <td>-80</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>8</td>
#       <td>NaN</td>
#       <td>1610612744</td>
#       <td>1630541</td>
#       <td>108</td>
#       <td>82</td>
#       <td>1630237.000</td>
#       <td>1610612747</td>
#       <td>6530000</td>
#       <td>4</td>
#       <td>42200233</td>
#       <td>2023-05-07T03:04:59.300Z</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#   </tbody>
#   <tfoot>
#     <tr><td colspan="24" style="text-align: left; font-size: 0.8em; color: #888; font-style: italic; padding: 4px 8px;">Showing 5 of 199,127 rows × 23 columns</td></tr>
#   </tfoot>
# </table></div></div></div>

# %% [markdown]
# # Implementation

# %% [markdown]
# # Sandbox
